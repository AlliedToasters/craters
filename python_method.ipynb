# %%
#from proposal_code import tiles
from test_human import invert_image
import matplotlib.pyplot as plt
import numpy as np
from scipy import ndimage
import time
import cv2
from skimage.draw import circle
import os

# %%
#img = np.array(tiles['3_24'])
img = cv2.imread('./tiles/raw/tile3_24.pgm')
#inv_img = invert_image(img)

# %%
plt.imshow(img);

# %%
#bilateral_filtered_image = cv2.bilateralFilter(img, 50, 175, 175)
#plt.imshow(bilateral_filtered_image);

# %%
edge_detected_image = cv2.Canny(img, 100, 10)
plt.imshow(edge_detected_image);

# %%
rr, cc = circle(300, 100, 50)

# %%
img[rr, cc] = 0
plt.imshow(img)
